# %% [markdown]
# # Neural Network

# %% [markdown]
# #### What is Neural Network  ?
#
# Netural networks are modeled after biological neural networks and attempt to allow computer to learn in a similar manner humans through reinforcement learning.
# ___
#
# #### Neural Network use cases ?
#
# 1. Pattern Recognition.
#
# 2. Time Series Predictions.
#
# 3. Signal Processing.
#
# 4. Anomaly Detection.
#
# 5. Control.
# ___
#
# #### Basic of Neural Network is ?
#
# It it come from the human brain, just like the brain has interconnected neurons with dendrites that receive inputs, and then based on those inputs, produce an electrical signal output through the axom.
#
# So this concept that going to be trying to recreate through artifical neural networks.
# ___
#
# #### Why to develop Neural Networks ?
#
# 1. These are problems that are difficult for humans but easy for computers(calculating large arithmetic problems).
#
# 2. Then there are problems easy for human, but difficult for computers(recognizing a picture of a person from the side).
#
# Neurla Networks attempt to solve problems that would normally easy for humans but hard for computers.
# ___
#
# #### What is Perceptron ?
#
# A perceptron consists of one or more inputs, a processor, and a single output.
#
# A perceptron follows the 'feed-forward' model, meaning inputs are sent into the neuron, are processe, and result in an output.
#
# A perceptron process follows 4 main steps:
#
# 1. Receive inputs.
# 2. Weight inputs.
# 3. Sum inputs.
# 4. Generate Output.
# ____
#
# #### What is the processing of the perceptron ?
#
# 1. Have many inputs.
# 2. Weighted, each input that is sent into the neuron first be weighted, multiplied by some value(often a number between -1 and 1).
# 3. So when creating a perceptron, it will typically begin by assigning random weights.
# 4. When have the inputs and weighted, we take each input and multiply it by its weight.
# 5. The output of a perceptron is generated by passing that sum through an activation function. In the case of a simple binary output, the activation function is what tells the perceptron whether to fire or not. There are many activation functions to choose from(Logistic, Trigonometirc etc), so make the activation function the sign of the sum. In other words, if the sum is a positive number, the output is 1, if it is negative, the output is -1.
# 6. One more thing is to consider Bias, if the input are equal to zero, then no matter what multiplicative weight would also be zero,
# 7. So it need to input the Bias in order to avoid this situation.
# ___
#
# #### Train the perceptron use the following steps are :
#
# 1. Provide the perceptron with inputs for which there is a known answer.
# 2. Ask the perceptron to guess an answer.
# 3. Compute the error, to know how far off from the correct answer?
# 4. Adjust all the weights according to the error.
# 5. Return to Step 1 and repeat.
#
# We repeat this until we reach an error we are satisfied with(we set this before hand).
# ___
#
# #### What is Neural Network layers ?
#
# You will have an input layer and an output layer, and between this two layer have a hidden layer, but you don't directly see anything but the input of output.
#
# The terms of 'Deep Learning', this is just a Neural Network with many hidden layders, so causing it to be deep.
